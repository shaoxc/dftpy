# %%
import os
import numpy as np
from dftpy.grid import DirectGrid
from dftpy.field import DirectField
from dftpy.functional import Functional, TotalFunctional
from dftpy.optimization import Optimization
from dftpy.constants import LEN_CONV, ENERGY_CONV
from dftpy.formats.vasp import read_POSCAR
from dftpy.td.propagator import Propagator
from dftpy.td.hamiltonian import Hamiltonian
from dftpy.utils.utils import calc_rho, calc_j
from dftpy.td.utils import initial_kick
from dftpy.mpi import pmi, sprint, mp
from dftpy.ions import Ions
#-----------------------------------------------------------------------
if pmi.size > 0:
    from mpi4py import MPI
    mp.comm = MPI.COMM_WORLD
#-----------------------------------------------------------------------
import ase
#drom ase.lattice.cubic import FaceCenteredCubic
from ase.md.velocitydistribution import MaxwellBoltzmannDistribution
from ase.io.trajectory import Trajectory
from ase.calculators.mixing import LinearCombinationCalculator, MixedCalculator, SumCalculator
from ase import units,Atoms

from ase.build import bulk, molecule
from ase.lattice.cubic import FaceCenteredCubic
from ase.md.langevin import Langevin
from ase.md.velocitydistribution import MaxwellBoltzmannDistribution
from ase.io.trajectory import Trajectory
from ase.md.verlet import VelocityVerlet
from ase.calculators.eam import EAM

from dftpy.config.config import DefaultOption, OptionFormat, PrintConf
from dftpy.api.api4ase import DFTpyCalculator

# %%
np.random.seed(8888)

# %%
size = 1 
a = 4.24068463425528 
T = 600.0  # Kelvin
DATA='../DATA/'
#atoms = Atoms('Al', positions=[(a/2,a/2,a/2)], pbc=False, cell=[[a, 0, 0], [0, a, 0], [0, 0, a]])
atoms =  bulk('Al', 'fcc', a=a, cubic=True)

ions = Ions.from_ase(atoms)

# %%
PP_list = {'Al': DATA+'al.lda.recpot'}
grid = DirectGrid(ecut=20, lattice=ions.cell, mp=mp)
rho = DirectField(grid=grid)

PSEUDO = Functional(type='PSEUDO', grid=grid, ions=ions, PP_list=PP_list)
KE = Functional(type='KEDF', name='TFvW')
XC = Functional(type='XC', name='LDA')
HARTREE = Functional(type='HARTREE')
#
funcDict = {'KE' :KE, 'XC' :XC, 'HARTREE' :HARTREE, 'PSEUDO' :PSEUDO}
EnergyEvaluator = TotalFunctional(**funcDict)
opt = {'econv': 1e-12,'maxiter': 500}
#
rho[:] = ions.get_ncharges() / ions.cell.volume
optimizer = Optimization(EnergyEvaluator=EnergyEvaluator, optimization_method='TN',optimization_options=opt )
# Out:
# setting key: Al -> ../DATA/al.lda.recpot

# %%
calcBO = DFTpyCalculator(optimizer = optimizer, evaluator = EnergyEvaluator, rho = rho)

# %%
nas = 1

conf = DefaultOption()
conf["PATH"]["pppath"] = DATA
conf["PP"]["Al"] = "al.lda.recpot"
conf["OPT"]["method"] = "TN"
conf["OPT"]["econv"] = 1e-12
conf["KEDF"]["kedf"] = "TFvW"
conf["JOB"]["calctype"] = "Energy Force"
conf["OUTPUT"]["time"] = False
conf["TD"]["single_step"] = True
conf["TD"]["max_pc"] = 2
conf["TD"]["timestep"] = 0.041341374575751*nas
conf["TD"]["strength"] = 0.00 
conf["GRID"]["cplx"] = True
conf["GRID"]["gfull"] = True
conf["GRID"]["ecut"] =  540
#conf["GRID"]["nr"] = "16 16 16"
conf["PROPAGATOR"]["propagator"] = "crank-nicholson"
conf["PROPAGATOR"]["tol"] = 1e-14
conf["PROPAGATOR"]["atol"] = 1e-14

conf = OptionFormat(conf)
PrintConf(conf)
# Out:
# {
#     "CASIDA": {
#         "diagonalize": true,
#         "numeig": null,
#         "tda": false
#     },
#     "CELL": {
#         "cellfile": "POSCAR",
#         "elename": null,
#         "format": null,
#         "zval": null
#     },
#     "DENSITY": {
#         "densityfile": null,
#         "densityini": "heg",
#         "densityoutput": null,
#         "magmom": 0,
#         "nspin": 1
#     },
#     "EXC": {
#         "c_str": null,
#         "libxc": [
#             "lda_x",
#             "lda_c_pz"
#         ],
#         "x_str": null,
#         "xc": null
#     },
#     "GRID": {
#         "cplx": true,
#         "ecut": 540,
#         "gfull": true,
#         "maxprime": 13,
#         "nr": null,
#         "scale": 0.99,
#         "spacing": 0.263884851105058
#     },
#     "INVERSION": {
#         "rho_in": null,
#         "v_out": null
#     },
#     "JOB": {
#         "calctype": [
#             "Energy",
#             "Force"
#         ],
#         "task": "Optdensity"
#     },
#     "KEDF": {
#         "alpha": null,
#         "beta": null,
#         "delta": null,
#         "etamax": 50,
#         "interp": "hermite",
#         "k_str": null,
#         "kdd": 3,
#         "kedf": "TFVW",
#         "kerneltype": null,
#         "kfmax": null,
#         "kfmin": null,
#         "ldw": null,
#         "lumpfactor": null,
#         "maxpoints": 1000,
#         "neta": 50000,
#         "nsp": null,
#         "order": 3,
#         "params": null,
#         "ratio": 1.15,
#         "rho0": null,
#         "rhomax": null,
#         "sigma": null,
#         "symmetrization": null,
#         "temperature": null,
#         "temperature0": null,
#         "x": 1,
#         "y": 1
#     },
#     "KEDF2": {
#         "active": false,
#         "alpha": null,
#         "beta": null,
#         "delta": null,
#         "etamax": 50,
#         "interp": "hermite",
#         "k_str": null,
#         "kdd": 3,
#         "kedf": "WT",
#         "kerneltype": null,
#         "kfmax": null,
#         "kfmin": null,
#         "ldw": null,
#         "lumpfactor": null,
#         "maxpoints": 1000,
#         "neta": 50000,
#         "nsp": null,
#         "order": 3,
#         "params": null,
#         "ratio": 1.15,
#         "rho0": null,
#         "rhomax": null,
#         "sigma": null,
#         "symmetrization": null,
#         "temperature": null,
#         "temperature0": null,
#         "x": 0,
#         "y": 0
#     },
#     "MATH": {
#         "linearie": true,
#         "linearii": true,
#         "multistep": 1,
#         "reuse": true,
#         "twostep": false
#     },
#     "MIX": {
#         "coef": 0.7,
#         "delay": 2,
#         "kf": "auto",
#         "maxm": 7,
#         "predcoef": [
#             1.0,
#             1.0,
#             1.0
#         ],
#         "predecut": null,
#         "predtype": "kerker",
#         "restarted": false,
#         "scheme": "pulay"
#     },
#     "NONADIABATIC": {
#         "cutoff": 0.01,
#         "k": 2,
#         "nonadiabatic": null,
#         "rho_cutoff": 0.001
#     },
#     "NONADIABATIC2": {
#         "active": false,
#         "cutoff": 0.01,
#         "k": 2,
#         "nonadiabatic": null,
#         "rho_cutoff": 0.001
#     },
#     "OPT": {
#         "algorithm": "EMM",
#         "c1": 0.0001,
#         "c2": 0.2,
#         "econv": 1e-12,
#         "h0": 1,
#         "maxfun": 50,
#         "maxiter": 100,
#         "maxls": 10,
#         "method": "TN",
#         "vector": "Orthogonalization",
#         "xtol": 1e-12
#     },
#     "OUTPUT": {
#         "electrostatic_potential": null,
#         "stress": true,
#         "time": false
#     },
#     "PATH": {
#         "cellpath": "./",
#         "pppath": "../DATA/"
#     },
#     "PP": {
#         "Al": "al.lda.recpot"
#     },
#     "PROPAGATOR": {
#         "atol": 1e-14,
#         "linearsolver": "cg",
#         "maxiter": 100,
#         "order": 20,
#         "propagator": "crank-nicholson",
#         "tol": 1e-14
#     },
#     "TD": {
#         "atol_pc": 1e-10,
#         "correction": false,
#         "direc": 0,
#         "max_pc": 2,
#         "max_runtime": 0,
#         "omega": 0,
#         "outfile": "td_out",
#         "propagate_vector_potential": true,
#         "restart": false,
#         "restart_input": "restart_data.npy",
#         "save_interval": 1000,
#         "single_step": true,
#         "strength": 0.0,
#         "timestep": 0.041341374575751,
#         "tmax": 1,
#         "tol_pc": 1e-08,
#         "vector_potential": false,
#         "z_split": 0
#     }
# }
# '{\n    "CASIDA": {\n        "diagonalize": true,\n        "numeig": null,\n        "tda": false\n    },\n    "CELL": {\n        "cellfile": "POSCAR",\n        "elename": null,\n        "format": null,\n        "zval": null\n    },\n    "DENSITY": {\n        "densityfile": null,\n        "densityini": "heg",\n        "densityoutput": null,\n        "magmom": 0,\n        "nspin": 1\n    },\n    "EXC": {\n        "c_str": null,\n        "libxc": [\n            "lda_x",\n            "lda_c_pz"\n        ],\n        "x_str": null,\n        "xc": null\n    },\n    "GRID": {\n        "cplx": true,\n        "ecut": 540,\n        "gfull": true,\n        "maxprime": 13,\n        "nr": null,\n        "scale": 0.99,\n        "spacing": 0.263884851105058\n    },\n    "INVERSION": {\n        "rho_in": null,\n        "v_out": null\n    },\n    "JOB": {\n        "calctype": [\n            "Energy",\n            "Force"\n        ],\n        "task": "Optdensity"\n    },\n    "KEDF": {\n        "alpha": null,\n        "beta": null,\n        "delta": null,\n        "etamax": 50,\n        "interp": "hermite",\n        "k_str": null,\n        "kdd": 3,\n        "kedf": "TFVW",\n        "kerneltype": null,\n        "kfmax": null,\n        "kfmin": null,\n        "ldw": null,\n        "lumpfactor": null,\n        "maxpoints": 1000,\n        "neta": 50000,\n        "nsp": null,\n        "order": 3,\n        "params": null,\n        "ratio": 1.15,\n        "rho0": null,\n        "rhomax": null,\n        "sigma": null,\n        "symmetrization": null,\n        "temperature": null,\n        "temperature0": null,\n        "x": 1,\n        "y": 1\n    },\n    "KEDF2": {\n        "active": false,\n        "alpha": null,\n        "beta": null,\n        "delta": null,\n        "etamax": 50,\n        "interp": "hermite",\n        "k_str": null,\n        "kdd": 3,\n        "kedf": "WT",\n        "kerneltype": null,\n        "kfmax": null,\n        "kfmin": null,\n        "ldw": null,\n        "lumpfactor": null,\n        "maxpoints": 1000,\n        "neta": 50000,\n        "nsp": null,\n        "order": 3,\n        "params": null,\n        "ratio": 1.15,\n        "rho0": null,\n        "rhomax": null,\n        "sigma": null,\n        "symmetrization": null,\n        "temperature": null,\n        "temperature0": null,\n        "x": 0,\n        "y": 0\n    },\n    "MATH": {\n        "linearie": true,\n        "linearii": true,\n        "multistep": 1,\n        "reuse": true,\n        "twostep": false\n    },\n    "MIX": {\n        "coef": 0.7,\n        "delay": 2,\n        "kf": "auto",\n        "maxm": 7,\n        "predcoef": [\n            1.0,\n            1.0,\n            1.0\n        ],\n        "predecut": null,\n        "predtype": "kerker",\n        "restarted": false,\n        "scheme": "pulay"\n    },\n    "NONADIABATIC": {\n        "cutoff": 0.01,\n        "k": 2,\n        "nonadiabatic": null,\n        "rho_cutoff": 0.001\n    },\n    "NONADIABATIC2": {\n        "active": false,\n        "cutoff": 0.01,\n        "k": 2,\n        "nonadiabatic": null,\n        "rho_cutoff": 0.001\n    },\n    "OPT": {\n        "algorithm": "EMM",\n        "c1": 0.0001,\n        "c2": 0.2,\n        "econv": 1e-12,\n        "h0": 1,\n        "maxfun": 50,\n        "maxiter": 100,\n        "maxls": 10,\n        "method": "TN",\n        "vector": "Orthogonalization",\n        "xtol": 1e-12\n    },\n    "OUTPUT": {\n        "electrostatic_potential": null,\n        "stress": true,\n        "time": false\n    },\n    "PATH": {\n        "cellpath": "./",\n        "pppath": "../DATA/"\n    },\n    "PP": {\n        "Al": "al.lda.recpot"\n    },\n    "PROPAGATOR": {\n        "atol": 1e-14,\n        "linearsolver": "cg",\n        "maxiter": 100,\n        "order": 20,\n        "propagator": "crank-nicholson",\n        "tol": 1e-14\n    },\n    "TD": {\n        "atol_pc": 1e-10,\n        "correction": false,\n        "direc": 0,\n        "max_pc": 2,\n        "max_runtime": 0,\n    ...

# %%
calcEF = DFTpyCalculator(rho=rho,config=conf,optimizer = optimizer, evaluator = EnergyEvaluator, mp =mp, step = nas)

# %%
calcFF =  EAM(potential=DATA+'Al_zhou.eam.alloy')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 calcFF =  EAM(potential=DATA+'Al_zhou.eam.alloy')
#
# File ~/anaconda3/lib/python3.11/site-packages/ase/calculators/eam.py:250, in EAM.__init__(self, restart, ignore_bad_restart_file, label, atoms, form, **kwargs)
#     247 self.form = form
#     249 if 'potential' in kwargs:
# --> 250     self.read_potential(kwargs['potential'])
#     252 Calculator.__init__(self, restart, ignore_bad_restart_file,
#     253                     label, atoms, **kwargs)
#     255 valid_args = ('potential', 'elements', 'header', 'drho', 'dr',
#     256               'cutoff', 'atomic_number', 'mass', 'a', 'lattice',
#     257               'embedded_energy', 'electron_density', 'phi',
#    (...)
#     260               'd', 'q', 'd_d', 'd_q',  # adp terms
#     261               'skin', 'Z', 'nr', 'nrho', 'mass')
#
# File ~/anaconda3/lib/python3.11/site-packages/ase/calculators/eam.py:292, in EAM.read_potential(self, filename)
#     287 """Reads a LAMMPS EAM file in alloy or adp format
#     288 and creates the interpolation functions from the data
#     289 """
#     291 if isinstance(filename, str):
# --> 292     with open(filename) as fd:
#     293         self._read_potential(fd)
#     294 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../DATA/Al_zhou.eam.alloy'

# %%
calcA = [calcFF,calcBO,calcEF]
weights = [1.0,-1.0,1.0]

calcT= LinearCombinationCalculator(calcA,weights) 

atoms.calc = calcT

# %%
MaxwellBoltzmannDistribution(atoms, temperature_K = T, force_temp=True)

#dyn = Langevin(atoms, 0.001 * units.fs, temperature_K = T,  friction = 0.1)
dyn = VelocityVerlet(atoms, .001 * nas * units.fs )

step = 0
interval = 1
def printenergy(a=atoms):
    global step, interval
    epot = a.get_potential_energy() 
    ekin = a.get_kinetic_energy() 
    sprint(
            "Step={:<8d} Epot={:.5f} Ekin={:.5f} T={:.3f} Etot={:.5f} ".format(
            step, epot, ekin, ekin / (1.5 * units.kB), epot + ekin
        )
    )
    sprint(a.get_forces())
    step += interval

def check_stop():
    if os.path.isfile('dftpy_stopfile'): exit()


traj = Trajectory("testing.traj", "w", atoms)

dyn.attach(check_stop, interval=1)
dyn.attach(printenergy, interval=1)
dyn.attach(traj.write, interval=1)

dyn.run(10000)
# Out:
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -8.199458735952E+00     -8.199459E+00   1.053102E+00    1       1       1.206040E-02
# 1       -8.424503649374E+00     -2.250449E-01   4.812652E-02    2       1       2.593756E-02
# 2       -8.431858222657E+00     -7.354573E-03   2.445270E-03    5       1       4.825282E-02
# 3       -8.432098935728E+00     -2.407131E-04   1.739177E-04    5       1       6.955218E-02
# 4       -8.432122522005E+00     -2.358628E-05   9.065846E-06    6       1       8.758616E-02
# 5       -8.432123012256E+00     -4.902511E-07   8.426012E-07    2       1       1.003754E-01
# 6       -8.432123122652E+00     -1.103955E-07   5.362376E-08    6       1       1.252122E-01
# 7       -8.432123127905E+00     -5.253385E-09   4.385821E-09    5       1       1.396940E-01
# 8       -8.432123128224E+00     -3.189271E-10   3.445510E-10    3       1       1.549060E-01
# 9       -8.432123128280E+00     -5.613821E-11   4.608570E-11    5       1       1.696799E-01
# 10      -8.432123128283E+00     -2.609468E-12   5.741270E-12    3       1       1.842077E-01
# 11      -8.432123128283E+00     -2.096101E-13   3.353836E-12    10      2       2.222834E-01
# 12      -8.432123128283E+00     -7.638334E-14   2.252567E-12    11      2       2.565455E-01
# #### Density Optimization Converged ####
# Chemical potential (a.u.): 0.23659729724521067
# Chemical potential (eV)  : 6.438140387661388
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  1.854761327069522E-01
#         II energy (eV): -2.802299826288640E+02
#    KEDF-TF energy (eV):  7.727604769767090E+01
#    KEDF-VW energy (eV):  4.473894518373625E+00
#     PSEUDO energy (eV):  5.223074783770513E+01
#         XC energy (eV): -8.338594100630020E+01
#      TOTAL energy (eV): -2.294497574487076E+02
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :              3.004254988806492
#   kedfs energy (eV)              :             81.749942216044545
#   total energy (a.u.)            :             -8.432123128283138
#   total energy (eV)              :           -229.449757448707572
#   total energy (eV/atom)         :            -57.362439362176893
# Calculate Force...
#               Max force (a.u.) : 0.00000
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.00000
# --------------------------------------------------------------------------------
# tddft step
# The final grid size is  [16 16 16]
# setting key: Al -> ../DATA//al.lda.recpot
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -8.199458735952E+00     -8.199459E+00   1.053102E+00    1       1       3.117561E-03
# 1       -8.424503641037E+00     -2.250449E-01   4.812674E-02    2       1       1.360512E-02
# 2       -8.431858682786E+00     -7.355042E-03   2.435086E-03    5       1       3.270197E-02
# 3       -8.432098983924E+00     -2.403011E-04   1.733055E-04    5       1       5.529928E-02
# 4       -8.432122523463E+00     -2.353954E-05   9.056345E-06    6       1       8.173752E-02
# 5       -8.432123012595E+00     -4.891324E-07   8.364768E-07    2       1       9.411716E-02
# 6       -8.432123122651E+00     -1.100555E-07   5.400592E-08    6       1       1.207936E-01
# 7       -8.432123127914E+00     -5.263393E-09   4.338602E-09    5       1       1.440940E-01
# 8       -8.432123128227E+00     -3.125837E-10   3.228127E-10    3       1       1.602697E-01
# 9       -8.432123128281E+00     -5.407763E-11   3.595729E-11    5       1       1.824565E-01
# 10      -8.432123128283E+00     -2.177813E-12   4.519015E-12    3       1       2.007141E-01
# 11      -8.432123128283E+00     -1.563194E-13   3.691949E-12    8       2       2.300725E-01
# 12      -8.432123128283E+00     -1.048051E-13   2.277392E-12    8       2       2.568429E-01
# #### Density Optimization Converged ####
# Chemical potential (a.u.): 0.236597297355115
# Chemical potential (eV)  : 6.438140390652038
# TDDFT STEP
# Convergence not reached for Predictor-corrector
# Diff in rho:   1.75e-05 >   5.34e-09
# Diff in j:   1.21e-04 >   1.00e-10
# Step=0        Epot=-9.72147 Ekin=0.31022 T=2400.000 Etot=-9.41124
# [[ 1.08157341e-07 -3.45364808e-08 -5.60620010e-08]
#  [ 1.08157341e-07 -3.45364804e-08 -5.60620006e-08]
#  [ 1.08157342e-07 -3.45364807e-08 -5.60620006e-08]
#  [ 1.08157342e-07 -3.45364804e-08 -5.60620010e-08]]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -8.432123128118E+00     -8.432123E+00   4.434351E-10    1       1       1.109838E-02
# 1       -8.432123128248E+00     -1.307132E-10   7.049436E-11    5       1       3.128481E-02
# 2       -8.432123128253E+00     -4.403589E-12   1.168560E-11    4       1       4.786754E-02
# 3       -8.432123128253E+00     -7.318590E-13   6.638527E-12    8       2       7.541490E-02
# 4       -8.432123128254E+00     -2.096101E-13   3.192610E-12    5       2       9.503436E-02
# #### Density Optimization Converged ####
# Chemical potential (a.u.): 0.23659729828048956
# Chemical potential (eV)  : 6.438140415832762
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  1.854762950677701E-01
#         II energy (eV): -2.802299826266407E+02
#    KEDF-TF energy (eV):  7.727604802010086E+01
#    KEDF-VW energy (eV):  4.473895243508774E+00
#     PSEUDO energy (eV):  5.223074674718166E+01
#         XC energy (eV): -8.338594112712327E+01
#      TOTAL energy (eV): -2.294497574479049E+02
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :              3.004255027303799
#   kedfs energy (eV)              :             81.749943263609637
#   total energy (a.u.)            :             -8.432123128253640
#   total energy (eV)              :           -229.449757447904886
#   total energy (eV/atom)         :            -57.362439361976222
# Calculate Force...
#               Max force (a.u.) : 0.00000
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.00000
# --------------------------------------------------------------------------------
# tddft step
# Convergence not reached for Predictor-corrector
# Diff in rho:   4.38e-05 >   5.33e-09
# Diff in j:   3.20e-04 >   1.00e-10
# Step=1        Epot=-9.99151 Ekin=0.31022 T=2400.000 Etot=-9.68128
# [[-1.01208853e-04  6.96748511e-05 -2.05706585e-05]
#  [ 1.93060344e-05 -4.11119506e-05 -3.08446700e-06]
#  [ 8.46971430e-05  7.56535120e-05  9.12886933e-05]
#  [ 1.21325284e-04  8.27535886e-06  3.22404967e-06]]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -8.432123128027E+00     -8.432123E+00   4.473354E-10    1       1       1.130962E-02
# 1       -8.432123128159E+00     -1.326352E-10   7.006343E-11    5       1       3.341985E-02
# 2       -8.432123128164E+00     -5.110579E-12   1.693896E-11    5       1       5.335021E-02
# 3       -8.432123128165E+00     -7.318590E-13   6.359225E-12    5       2       7.347202E-02
# 4       -8.432123128165E+00     -1.243450E-13   5.237397E-12    9       2       1.162953E-01
# #### Density Optimization Converged ####
# Chemical potential (a.u.): 0.23659729828749523
# Chemical potential (eV)  : 6.438140416023396
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  1.854762987655060E-01
#         II energy (eV): -2.802299826199709E+02
#    KEDF-TF energy (eV):  7.727604802495054E+01
#    KEDF-VW energy (eV):  4.473895175849662E+00
#     PSEUDO energy (eV):  5.223074680321226E+01
#         XC energy (eV): -8.338594112830644E+01
#      TOTAL energy (eV): -2.294497574454994E+02
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :              3.004255024995595
#   kedfs energy (eV)              :             81.749943200800203
#   total energy (a.u.)            :             -8.432123128165241
#   total energy (eV)              :           -229.449757445499444
#   total energy (eV/atom)         :            -57.362439361374861
# Calculate Force...
#               Max force (a.u.) : 0.00000
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.00000
# --------------------------------------------------------------------------------
# tddft step
# Convergence not reached for Predictor-corrector
# Diff in rho:   5.52e-05 >   5.33e-09
# Diff in j:   4.30e-04 >   1.31e-10
# Step=2        Epot=-10.34213 Ekin=0.31022 T=2400.000 Etot=-10.03190
# [[-3.27132591e-04  1.17323337e-04  1.82911534e-05]
#  [ 8.30971671e-04 -2.40986028e-05 -3.59641205e-04]
#  [-3.14724650e-05  1.74905555e-04  5.46721456e-04]
#  [ 3.20465045e-04  4.49389255e-04  2.47668622e-04]]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -8.432123127879E+00     -8.432123E+00   4.518752E-10    1       1       1.037025E-02
# 1       -8.432123128012E+00     -1.332037E-10   6.748563E-11    5       1       2.754402E-02
# 2       -8.432123128017E+00     -5.339729E-12   1.455216E-11    5       1       4.322910E-02
# 3       -8.432123128018E+00     -6.448175E-13   6.551309E-12    6       2       6.537867E-02
# 4       -8.432123128018E+00     -1.492140E-13   4.078968E-12    6       2       9.025478E-02
# #### Density Optimization Converged ####
# Chemical potential (a.u.): 0.23659729828286277
# Chemical potential (eV)  : 6.43814041589734
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  1.854763036809610E-01
#         II energy (eV): -2.802299826088546E+02
#    KEDF-TF energy (eV):  7.727604802633590E+01
#    KEDF-VW energy (eV):  4.473895153745619E+00
#     PSEUDO energy (eV):  5.223074681268070E+01
#         XC energy (eV): -8.338594112908342E+01
#      TOTAL energy (eV): -2.294497574414949E+02
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :              3.004255024234197
#   kedfs energy (eV)              :             81.749943180081516
#   total energy (a.u.)            :             -8.432123128018077
#   total energy (eV)              :           -229.449757441494910
#   total energy (eV/atom)         :            -57.362439360373727
# Calculate Force...
#               Max force (a.u.) : 0.00000
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.00000
# --------------------------------------------------------------------------------
# tddft step
# Convergence not reached for Predictor-corrector
# Diff in rho:   5.87e-05 >   5.33e-09
# Diff in j:   4.75e-04 >   1.83e-10
# Step=3        Epot=-10.67728 Ekin=0.31022 T=2400.000 Etot=-10.36706
# [[-6.63362795e-04  1.43535137e-04  1.11299670e-04]
#  [ 2.35957009e-03  4.55335976e-05 -1.03624750e-03]
#  [-3.31650330e-04  2.94162190e-04  1.32977712e-03]
#  [ 5.86789108e-04  1.28230962e-03  7.09961771e-04]]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -8.432123127672E+00     -8.432123E+00   4.509178E-10    1       1       1.133084E-02
# 1       -8.432123127806E+00     -1.339249E-10   6.968882E-11    5       1       2.632928E-02
# 2       -8.432123127811E+00     -4.719780E-12   1.273351E-11    4       1       4.175806E-02
# 3       -8.432123127812E+00     -6.306067E-13   9.743425E-12    7       2       7.233691E-02
# 4       -8.432123127812E+00     -4.103384E-13   9.903398E-13    2       1       8.523297E-02
# 5       -8.432123127812E+00     -3.907985E-14   1.282073E-12    14      2       1.377985E-01
# #### Density Optimization Converged ####
# Chemical potential (a.u.): 0.23659729828176823
# Chemical potential (eV)  : 6.438140415867556
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  1.854763098374373E-01
#         II energy (eV): -2.802299825932919E+02
#    KEDF-TF energy (eV):  7.727604803277603E+01
#    KEDF-VW energy (eV):  4.473895198455822E+00
#     PSEUDO energy (eV):  5.223074674813897E+01
#         XC energy (eV): -8.338594113180720E+01
#      TOTAL energy (eV): -2.294497574358908E+02
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :              3.004255026113937
#   kedfs energy (eV)              :             81.749943231231839
#   total energy (a.u.)            :             -8.432123127812131
#   total energy (eV)              :           -229.449757435890831
#   total energy (eV/atom)         :            -57.362439358972708
# Calculate Force...
#               Max force (a.u.) : 0.00001
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.00000
# --------------------------------------------------------------------------------
# tddft step
# Convergence not reached for Predictor-corrector
# Diff in rho:   5.74e-05 >   5.33e-09
# Diff in j:   4.75e-04 >   2.24e-10
# Step=4        Epot=-10.92745 Ekin=0.31022 T=2400.001 Etot=-10.61723
# [[-0.00108956  0.0001515   0.00024863]
#  [ 0.00447388  0.00015888 -0.00197467]
#  [-0.00078292  0.00042866  0.00237967]
#  [ 0.00090724  0.00243496  0.00135044]]
# Step    Energy(a.u.)            dE              dP              Nd      Nls     Time(s)
# 0       -8.432123127408E+00     -8.432123E+00   4.463476E-10    1       1       1.243019E-02
# 1       -8.432123127542E+00     -1.335909E-10   6.793444E-11    5       1       3.418922E-02
# 2       -8.432123127546E+00     -4.348522E-12   1.330575E-11    4       1       5.144334E-02
# 3       -8.432123127547E+00     -7.833734E-13   7.201585E-12    8       2       8.024859E-02
# 4       -8.432123127547E+00     -2.007283E-13   4.057748E-12    8       2       1.078510E-01
# #### Density Optimization Converged ####
# Chemical potential (a.u.): 0.23659729830712461
# Chemical potential (eV)  : 6.438140416557538
# Calculate Energy/Potential...
# -------------------------------Energy information-------------------------------
#    HARTREE energy (eV):  1.854763174185179E-01
#         II energy (eV): -2.802299825732826E+02
#    KEDF-TF energy (eV):  7.727604805776558E+01
#    KEDF-VW energy (eV):  4.473895480782095E+00
#     PSEUDO energy (eV):  5.223074643058830E+01
#         XC energy (eV): -8.338594114194915E+01
#      TOTAL energy (eV): -2.294497574286773E+02
# --------------------------------------------------------------------------------
#   kedfs energy (a.u.)            :              3.004255037407586
#   kedfs energy (eV)              :             81.749943538547669
#   total energy (a.u.)            :             -8.432123127547037
#   total energy (eV)              :           -229.449757428677259
#   total energy (eV/atom)         :            -57.362439357169315
# Calculate Force...
#               Max force (a.u.) : 0.00001
#               Min force (a.u.) : 0.00000
#               Ave force (a.u.) : 0.00000
# --------------------------------------------------------------------------------
# tddft step
# Convergence not reached for Predictor-corrector
# Diff in rho:   5.16e-05 >   5.32e-09
# Diff in j:   4.38e-04 >   2.53e-10
# Step=5        Epot=-11.06582 Ekin=0.31022 T=2400.002 Etot=-10.75560
# [[-0.00157949  0.00014394  0.00041824]
#  [ 0.00701121  0.00030411 -0.00310306]
#  [-0.00134642  0.00057187  0.00362078]
#  [ 0.00126356  0.00381906  0.00211959]]
# KeyboardInterrupt
